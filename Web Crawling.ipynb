# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
tom = urlopen("http://en.wikipedia.org/wiki/Tom_Cruise")
bsobj= BeautifulSoup(tom.read())
soup = BeautifulSouup(page.content,'html.parser')

for link in bsobj.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
print()
print()
print()

for link in bsobj.find('div',{'id':'bodyContent'}).find_all('a',href = re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])
print()
print()
print()
        
t = soup.find_all(id ='cite_ref-Block_1-0')
print(t)

listt =
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Tom_Cruise_(disambiguation)
# /wiki/File:Tom_Cruise_by_Gage_Skidmore_2.jpg
# /wiki/Syracuse,_New_York
# /wiki/Tom_Cruise_filmography
# /wiki/Mimi_Rogers
# /wiki/Nicole_Kidman
# /wiki/Katie_Holmes
# /wiki/William_Mapother
# /wiki/List_of_awards_and_nominations_received_by_Tom_Cruise
# http://tomcruise.com
# /wiki/File:Tom_Cruise_signature.svg
# /wiki/List_of_awards_and_nominations_received_by_Tom_Cruise
# /wiki/Golden_Globe_Awards
# /wiki/Academy_Awards
# #cite_note-Block-1
# /wiki/Tom_Cruise_filmography
# #cite_note-auto-2
# #cite_note-3
# /wiki/Risky_Business
# /wiki/Top_Gun
# /wiki/The_Color_of_Money
# /wiki/Rain_Man
# /wiki/Born_on_the_Fourth_of_July_(film)
# /wiki/Ron_Kovic
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Motion_Picture_Drama
# /wiki/Academy_Award_for_Best_Actor
# /wiki/A_Few_Good_Men
# /wiki/The_Firm_(1993_film)
# /wiki/Interview_with_the_Vampire_(film)
# /wiki/Jerry_Maguire
# ...
